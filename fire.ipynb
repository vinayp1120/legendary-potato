# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayp1120/legendary-potato/blob/main/fire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Jul 26 02:09:17 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 325 (delta 159), reused 156 (delta 156), pack-reused 107
# Receiving objects: 100% (325/325), 2.23 MiB | 26.92 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 966.4 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 55.7 MB/s eta 0:00:00

# %%
# !pip install -q roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.7 MB/s eta 0:00:00

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="g6B7lbsTV9ZalEEfjXrF")
project = rf.workspace("weapon-detection-ohetg").project("wildfirenew")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to wildfirenew-1 in yolov9:: 100%|██████████| 1364/1364 [00:00<00:00, 5659.99it/s]

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 16 --epochs 25 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-07-26 02:11:14.984395: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-26 02:11:14.984460: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-26 02:11:15.105600: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-26 02:11:15.351267: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: zip a folder command

# !zip -r model.zip /content/yolov9
# Out:
#   adding: content/yolov9/ (stored 0%)
#   adding: content/yolov9/wildfirenew-1/ (stored 0%)
#   adding: content/yolov9/wildfirenew-1/README.dataset.txt (deflated 14%)
#   adding: content/yolov9/wildfirenew-1/valid/ (stored 0%)
#   adding: content/yolov9/wildfirenew-1/valid/labels/ (stored 0%)
#   adding: content/yolov9/wildfirenew-1/valid/labels/Img_1642_jpg.rf.27b6e6a9c137484efa69c8c58ab919a4.txt (deflated 22%)
#   adding: content/yolov9/wildfirenew-1/valid/labels/Img_329_jpg.rf.31e45ac57ec2f56dc028f15c14580227.txt (deflated 18%)
#   adding: content/yolov9/wildfirenew-1/valid/labels/Img_1599_jpg.rf.87f0a48dcd0c07a7d18010445d9ef90c.txt (deflated 37%)
#   adding: content/yolov9/wildfirenew-1/valid/labels/Img_1754_jpg.rf.3ae56b25919a9fcb3144513d1c96c31d.txt (deflated 32%)
#   adding: content/yolov9/wildfirenew-1/valid/labels/Img_1111_jpg.rf.a68e45ae51a098215f86098888b214dc.txt (deflated 18%)
# ...

# %%
# prompt: copy a zip file from google colab into drive

# !cp /content/yolov9/model.zip /content/drive/MyDrive
